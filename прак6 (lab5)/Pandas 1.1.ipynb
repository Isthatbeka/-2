# %%
import pandas as pd
df_1=pd.read_csv('mutant.txt', sep='\t')
df_2=pd.read_csv('wild_type.txt', sep='\t')
df_1.plot('Concentration, nM', 'Response',ylabel='Response',title='mutant')
df_2.plot('Concentration, nM', 'Response',ylabel='Response',title='wilde_type')
# Out:
# <AxesSubplot:title={'center':'wilde_type'}, xlabel='Concentration, nM', ylabel='Response'>
