# %%
import pandas as pd
import os

getway = '/home-local/student/Desktop/107'
beka = os.listdir(getway)
beka1 = []
for file in beka:
    way, file_type = os.path.splitext(file)
    if file_type == '.txt':
            beka1.append(file)
        
       
        
def risovat(file):
    for i in range (1):
        df = pd.read_csv(file, sep = '\t', skiprows= 42)
        del df['Step (s)']
        dfnew = df[(df['Time (min)'] >=4) & (df['Time (min)'] <=7)]
        print(dfnew)
        
        
for file in beka1:
    risovat(file)
# Out:
#       Time (min)  Value (mAU)
# 2400    4.000000    -0.395123
# 2401    4.001667    -0.394583
# 2402    4.003333    -0.397088
# 2403    4.005000    -0.400851
# 2404    4.006667    -0.403567
# ...          ...          ...
# 4196    6.993333     0.020533
# 4197    6.995000     0.015021
# 4198    6.996667     0.009710
# 4199    6.998333     0.005610
# 4200    7.000000     0.003378
#
# [1801 rows x 2 columns]
#       Time (min)  Value (mAU)
# 2400    4.000000    -0.267118
# 2401    4.001667    -0.266089
# 2402    4.003333    -0.263918
# 2403    4.005000    -0.261500
# 2404    4.006667    -0.259791
# ...          ...          ...
# 4196    6.993333     3.591543
# 4197    6.995000     3.588327
# 4198    6.996667     3.583005
# 4199    6.998333     3.576311
# 4200    7.000000     3.570408
#
# [1801 rows x 2 columns]
#       Time (min)  Value (mAU)
# 2400    4.000000    -5.628900
# 2401    4.001667    -5.630673
# 2402    4.003333    -5.633808
# 2403    4.005000    -5.637710
# 2404    4.006667    -5.641611
# ...          ...          ...
# 4196    6.993333    -4.537274
# 4197    6.995000    -4.535057
# 4198    6.996667    -4.532260
# 4199    6.998333    -4.530711
# 4200    7.000000    -4.531436
#
# [1801 rows x 2 columns]
#       Time (min)  Value (mAU)
# 2400    4.000000    -0.244251
# 2401    4.001667    -0.242950
# 2402    4.003333    -0.243417
# 2403    4.005000    -0.245789
# 2404    4.006667    -0.248980
# ...          ...          ...
# 4196    6.993333     0.853709
# 4197    6.995000     0.856263
# 4198    6.996667     0.858551
# 4199    6.998333     0.861362
# 4200    7.000000     0.865290
#
# [1801 rows x 2 columns]
#       Time (min)  Value (mAU)
# 2400    4.000000    -0.135986
# 2401    4.001667    -0.133346
# 2402    4.003333    -0.129929
# 2403    4.005000    -0.126812
# 2404    4.006667    -0.125120
# ...          ...          ...
# 4196    6.993333     1.592557
# 4197    6.995000     1.586301
# 4198    6.996667     1.582236
# 4199    6.998333     1.579551
# 4200    7.000000     1.576908
#
# [1801 rows x 2 columns]
#       Time (min)  Value (mAU)
# 2400    4.000000    -0.189998
# 2401    4.001667    -0.189990
# 2402    4.003333    -0.190909
# 2403    4.005000    -0.193115
# 2404    4.006667    -0.196144
# ...          ...          ...
# 4196    6.993333     1.004657
# 4197    6.995000     1.001643
# 4198    6.996667     0.996863
# 4199    6.998333     0.990982
# 4200    7.000000     0.984305
#
# [1801 rows x 2 columns]
